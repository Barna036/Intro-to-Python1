# %% [markdown]
# <a href="https://colab.research.google.com/github/Barna036/Intro-to-Python1/blob/main/Day_1_Scratch_Code_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# #type of object
# scaler /primitive
# int type= 100, -5
# float type =52.3 or -3.1416
# bool type or logical type = True or False; not like R TRUE
# str strings like "BErnie sanders" or "House resolution"
#
#
# -----If I need to convert it to covert it from string to int,

# %%
#coverting str to int
a = 3.999
int(a) #rule, always takes the digit before the decimal point
# Out:
# 3

# %%
#coverting booliean to int
b=True
int(b) # true as a logical always evaluate as 1, false as 0
# Out:
# 1

# %%
#int to float convert
c=5
float(5) # automatically convert to decimal
# Out:
# 5.0

# %%
test0=5.6
type(test0)
round(test0)
# Out:
# 6

# %%
#int and float are the examples of functions
test = 5.4
round(test)
# Out:
# 5

# %% [markdown]
# ##
# // floor division
# ** exponentiation
# % modulus
# - subtraction
# ```
# # This is formatted as code
# ```

# %%
radium=5
area=pi* (r**2)
area
# Out:
# 250000

# %%
pi=10000

# %% [markdown]
# # not recycling variable names recommended
# pi=10000

# %% [markdown]
# #strings: assign value to strings
# assign strings by signle or double quotation marks
# tripple quotation= multi line strings

# %%
inch = 5
metric = 2.54
cm = (inch* metric)
cm
# Out:
# 12.7

# %%
bb= "where should i go"
print(bb)
# Out:
# where should i go

# %%
new_word = city[0] + city [6]
print(new_word)
# Out:
# Ab

# %%
city = "Ann Arbor"
print(city[-4])
# Out:
# r

# %%
Date= "July6, 2026"
year = (Date[-4]+  Date[-3]+ Date [-2]+ Date [-1])
year
# Out:
# '2026'

# %%
Date= "July6, 2026"
year_forward = Date[8]+  Date[9]+ Date [10]
year_forward
# Out:
# '026'

# %%
year= Date[-4:] # slicing
year
# Out:
# '2026'

# %%
#f, or formatted, strings, are a convenient way to embed python objects inside of strings.
name = "jane"
message = f"Hello, {name}!"
print(message)
# Out:
# Hello, jane!

# %%
x=10
y=5
result = f"the sum of {x} and {y} is {x+y}"
print (result)
# Out:
# the sum of 10 and 5 is 15

# %%
#Boolean Logic
x=10
y= x> 4
print (y) # Y as a boolean its been saves
# Out:
# True

# %%
x=13
compare= (x<=10)
compare
party= "democrat"
is_party = (party == "democrat") # = is assignment, == is comparison. Confusing them is the single most common beginner mistake
is_party
# Out:
# True

# %%
print (bool(0), bool(42), bool (""), bool ("hello"))
#bool() converts any value to a boolean
#True: any non-zero number, any non empty-string
#False: 0, empty string
#True is 1, False is 0.
#str() will return the boolean as a string
# Out:
# False True False True

# %% [markdown]
# can convert from boolean to int or string
# true is 1, flase is 0
# str() will return the boolean as string
# use as conditionals
# # **If statement**

# %%
chance_of_rain = 0.62

if chance_of_rain > 0.90:
 print("Take an Umbrella!") # need a space to make it printable
else:
  print( "Leave it at home.")
# Out:
# Leave it at home.

# %%
number = int(input('What is your favorite number?'))
my_fav = 5
if my_fav == number:  ## if statements need a : after the condition
    print('We have the same favorite number')
    ## indentation is part of Python's syntax (more tomorrow)
else:
    print("We don't have the same favorite number")
# Out:
# What is your favorite number?5
# We have the same favorite number

# %%
day= input("what day is it")
if day.lower()=="Friday": # for lowercase, .upper for uppercase
  print("Friday I ma in love")
else:
  print("I am not in love")
# Out:
# what day is itsaturday
# I am not in love

# %%
home_cost=int(input("How much does your home cost?"))
available_fund= int(input("How much money do you have immediately available?"))
down_payment = home_cost*0.2
if available_fund> = down_payment:
  print("you can afford the home")
else:
    print("you cannot afford the home")
# Out:
# How much does your home cost?2
# How much money do you have immediately available?2
# you can afford the home
