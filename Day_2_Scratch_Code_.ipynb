# %% [markdown]
# <a href="https://colab.research.google.com/github/Barna036/Intro-to-Python1/blob/main/Day_2_Scratch_Code_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Three ways same result
# For robust code, couple of ways to do if in survey people type small f or so!
# #oprion 1: explicit OR
# If Day== "Friday" or Day == "friday":
# #option 2:  normalizze first
# if day.lower ()== "friday":
#
# #option 3: memeberhsip test
# if Day in ( "Friday", " friday", "friyay")
#
# #Boolean Overview
# if statement and logical test

# %%
name = input("What is your name?")

my_name="Will"

if name.lower() == my_name.lower() :
   print(f"hi (name.lower())")
# Out:
# What is your name?will
# hi (name.lower(john))

# %% [markdown]
# #logical operator as booleans
# in R Or is a pipe/ | but in here it work as arrays but not as simple boolean logic, stick with or, and and
# if we define i million >0, then not a is FAlse, false if a is true.
# a or b is true if at least one of a or b is true
# a and b is true if and only if both true
# Example: Bike= true, bus=false print (not bus) will give  true and
# print (bus or bike) will give true, but print (bus and bike) will give false.

# %%
# in control flow first is if condiuton, if I check for true, then if it is intended to


if <condition>: # condition is true, then works otherwise bipass it, always use :
  <expression 1>
  <expression 2>
  <expression 3>
else:
  <expression 4>
  some other code

# %%
earned = int(input("How much money did you earn?"))
spent= int(input("How much money did you spent?"))
if earned > spent:
  print("Great Job")
# Out:
# How much money did you earn?10
# How much money did you spent?2
# Great Job

# %%
votes_a = int(input("How many votes did candidate A gets"))
votes_b= int(input("How many votes did candidate B gets"))
if votes_a > votes_b:
  print("Candidate A wins")
# Out:
# How many votes did candidate A gets2
# How many votes did candidate B gets6

# %%
#Multiple condition and Branching

# %%
earned = float(input("How much money did you earn?"))
spent= float(input("How much money did you spent?"))
if earned > spent:
  print("Great Job")
if earned == spent:
  print("You are spending what you earned")
if earned < spent:
  print("spend less!")
# Out:
# How much money did you earn?3
# How much money did you spent?2
# Great Job

# %% [markdown]
# need to make decision
# Is X true? Complete task Y,
# Fals,  complete task Z instead, continue

# %%
age= float(input("How old are you?"))
if age >= 18:
  print("Eligible to vote")
else:
  print("sorry underage")
# Out:
# How old are you?21
# Eligible to vote
# sorry underage

# %% [markdown]
# # nesting statement
# if condition:
#   if condition:
#     <expression>
#   else:
#     <expression>
# else:
#   <expression>
#   #evaluate only when the first one is true

# %%
age= float(input("How old are you?"))
registered = (input("are you registred to vote?")).lower()
if age >= 18:
  print("Eligible to vote")
  if registered == "yes":
    print("Eligible to vote")
  else:
    print("sorry not registered")
else:
  print("sorry underage")
# Out:
# How old are you?18
# are you registred to vote?yes
# Eligible to vote

# %%
is_registered = False
is_in_right_location= False
if is_registered  and is_in_right_location:
  print("You can vote here!")
elif not is_in_right_location and is_registered:
  print("go to the right precinct")
else:
  print("cast a provitional ballot")
# Out:
# cast a provitional ballot

# %%
weather =(input("whats the weather like today?")).lower()

if weather == "rainy":
  print("grab an Umbrella")
elif weather == "sunny":
 print("grab some shade")
elif weather == "cloudy":
  cold = input("is it cold?").lower()
  if cold == "yes":
    print("Put on a coat")
  else:
    print("a long sleeve is fine")
else:
  print("put on something comfy")
# Out:
# whats the weather like today?cold
# put on something comfy

# %% [markdown]
# # **Loops**
# useful if I want to appy on multiple data items over and over again, it is like apply and tidy options.
# ### R has slower loops but python is more efficient
# ### two loops : for and while
# Common syntax:
# index=0 #declare an index
# while

# %%
while <condition>
<expression>
<expression>

# %%
#Program to display number 1 to 5
i=1
n=5
#while loop from i=1 to 5
while i<= n:
  i +=1 # this will update the condition

# %%
number = 701

while number % 13 !=0:
  print( f"{number} is not divisible by 13")
  number +=1
(print( f"{number} is tbe smallest number than 700 and divisible by 13"))
# Out:
# 701 is not divisible by 13
# 702 is tbe smallest number than 700 and divisible by 13

# %%
# A list of names
names = ["Alice", "Bob", "Charlie"]

# A list of languages to greet in
languages = ["English", "Spanish", "French"]

# Outer loop: step through each person
i = 0
while i < len(names):
    name = names[i]

    # Inner loop: for the current person, greet in each language
    j = 0
    while j < len(languages):
        lang = languages[j]
        if lang == "English":
            greeting = "Hello"
        elif lang == "Spanish":
            greeting = "¡Hola!"
        elif lang == "French":
            greeting = "Bonjour"
        else:
            greeting = "Hi"

        print(f"{greeting}, {name}!")
        j += 1

    # Move to the next person
    i += 1
# Out:
# Hello, Alice!
# ¡Hola!, Alice!
# Bonjour, Alice!
# Hello, Bob!
# ¡Hola!, Bob!
# Bonjour, Bob!
# Hello, Charlie!
# ¡Hola!, Charlie!
# Bonjour, Charlie!

# %%
n = 1
while n <= 50:
    count = 0
    m = n
    while m % 13 != 0:
        count += 1
        m += 1
    print(f"{n} reaches a multiple of 13 ({m}) after {count} steps.")
    n += 1
# Out:
# 1 reaches a multiple of 13 (13) after 12 steps.
# 2 reaches a multiple of 13 (13) after 11 steps.
# 3 reaches a multiple of 13 (13) after 10 steps.
# 4 reaches a multiple of 13 (13) after 9 steps.
# 5 reaches a multiple of 13 (13) after 8 steps.
# 6 reaches a multiple of 13 (13) after 7 steps.
# 7 reaches a multiple of 13 (13) after 6 steps.
# 8 reaches a multiple of 13 (13) after 5 steps.
# 9 reaches a multiple of 13 (13) after 4 steps.
# 10 reaches a multiple of 13 (13) after 3 steps.
# 11 reaches a multiple of 13 (13) after 2 steps.
# 12 reaches a multiple of 13 (13) after 1 steps.
# 13 reaches a multiple of 13 (13) after 0 steps.
# 14 reaches a multiple of 13 (26) after 12 steps.
# 15 reaches a multiple of 13 (26) after 11 steps.
# 16 reaches a multiple of 13 (26) after 10 steps.
# 17 reaches a multiple of 13 (26) after 9 steps.
# 18 reaches a multiple of 13 (26) after 8 steps.
# 19 reaches a multiple of 13 (26) after 7 steps.
# 20 reaches a multiple of 13 (26) after 6 steps.
# ...

# %%
count =0
m = 1
while m % 13!=0:
    count+=1
    m+=1
print(f"{n} reaches a multiple of {m} after {count} steps")
# Out:
# 5 reaches a multiple of 13 after 12 steps

# %%
# notes on range
#by default, start =0 and step =1
#only stop is requiredm start and step are optional
#will loop from strt until stop -1

# %%
for i in range(1,5):
  print(i) # doesnt print last digit=5
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,30, 5):
  print(i) # last one is the step size

  #for i in range(1,-30, -5):
   #print(i) # neg step and go down
# Out:
# 1
# -4
# -9
# -14
# -19
# -24
# -29

# %%
#complex for loop
fruits =["apple", "banana", "cherry", "pinaple"]
for veg in fruits:
  print(veg) # veg is referring the element in the object
# Out:
# apple
# banana
# cherry
# pinaple

# %%
words= ["apple", "banana", "cherry", "pinaple"]
by_letter={}

for word in words:
  letter=word[0]
  if letter not in by_letter:
    by_letter [letter]= [word]
  else:
    by_letter[letter].append(word)
print(by_letter)
#what will this code do?
# Out:
# {'a': ['apple'], 'b': ['banana'], 'c': ['cherry'], 'p': ['pinaple']}

# %%
name = "CLEMSON"
for char in "CLEMSON":
  print(char+"!")
# Out:
# C!
# L!
# E!
# M!
# S!
# O!
# N!

# %%
fruits =["apple", "banana", "cherry", "pinapple", "kiwi"]
short_fruit = []
long_fruit = []
for fruit in fruits:
  if len(fruit) < 6:
    short_fruit.append(fruit)
  else:
    long_fruit.append(fruit)
short_fruit
# Out:
# ['apple', 'kiwi']

# %%
for i in range(1, 4):
  for j in range(1, 4):
    if i == 2 and j == 2:
      break # break will only exist the inner loop
  print(i, j) # why is this output we get?
# Out:
# 1 3
# 2 2
# 3 3

# %%
fruits =["apple", "banana", "cherry", "pinapple", "kiwi"]
for fruit in fruits:
  if fruit == "carrot":
   break
  print(fruit)
# Out:
# apple
# banana
# cherry
# pinapple
# kiwi
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2326/3924857212.py in <cell line: 0>()
#       5   print(fruit)
#       6   fruits[-1]
# ----> 7 fruit[2] = "cherry"
#       8 print(fruit)
#
# TypeError: 'str' object does not support item assignment

# %%
#datatypes that are actually use to store data.
#lists one of the four basic data types
#python start start at zero not 1, so we need 0 indexing

# %%
my_fav_fruits = ["Peaches", "Raspberries", "Blueberries", "Mangoes"]
my_list = ["cactus", 42, False] #list can be differnt type
my_list

# %%
#methods
#len() was a functin that we called on a list: they have append, reverse, sort
#append adds an item to the list
teams = ["red.sox", "graves", "cubs"]
teams.append("giant")
print(teams)
# Out:
# ['red.sox', 'graves', 'cubs', 'giant']

# %%
#list. insert(index, element)
#what is index, what is object, what is
teams.insert(1, "philies") #adds phili is 1st position
teams
# Out:
# ['red.sox', 'philies', 'graves', 'cubs', 'giant']

# %%
teams.sort(key=len, reverse=True) # sort will list alpabetic order, () means a->z and revese is outherwise
 # shortest to the longest
print(teams)
# Out:
# ['philies', 'red.sox', 'graves', 'giant', 'cubs']

# %% [markdown]
# # Difference betweeen fucntion and method

# %%
teams = ["red.sox", "graves", "cubs", "graves"]
print(sorted(teams))  # sorted function doesnt update the object
# Out:
# ['cubs', 'graves', 'red.sox']

# %%
teams.index("graves") # to check if something is in the list or not
# Out:
# 1

# %%
#extend allows to add another things to the list
new_teams =["Marlins", "Rays", "Diamondbacks"]
teams.extend(new_teams)
teams
# Out:
# ['red.sox',
#  'graves',
#  'cubs',
#  'Marlins',
#  'Rays',
#  'Diamondbacks',
#  'Marlins',
#  'Rays',
#  'Diamondbacks',
#  'Marlins',
#  'Rays',
#  'Diamondbacks']

# %%
teams.remove("cubs")
print(teams)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2326/603187973.py in <cell line: 0>()
# ----> 1 teams.remove("cubs")
#       2 print(teams)
#
# ValueError: list.remove(x): x not in list

# %%
teams[:2]
teams[::2]
# Out:
# ['red.sox', 'Marlins', 'Diamondbacks', 'Rays', 'Marlins', 'Diamondbacks']

# %%
choice = [ "apple", "banana", "cherry", "Dino"]
choice.insert(2, "philies")
new_choice =["Marlins", "Rays", "Diamondbacks"]
choice.extend(new_choice)
choice.remove("banana")
choice.sort()
choice[:3]
# Out:
# ['Diamondbacks', 'Dino', 'Marlins']

# %%
schools = ['clemson','univ of carolina', 'usa', 'georgia']
schools.insert(2, 'michigan')
schools
# Out:
# ['clemson', 'univ of carolina', 'michigan', 'usa', 'georgia']

# %%
worse.schools= ['the ohio state', 'michigan']
schools.extend(worse.schools)

# %%
schools.pop(1)
# Out:
# 'univ of carolina'

# %%
schools[-3:]
# Out:
# ['michigan', 'usa', 'georgia']

# %%
i=0
while i < len(schools):
  print(schools[i])
  i +=1
# Out:
# clemson
# michigan
# usa
# georgia

# %%
# toubples are order sequences of items
#unlike list they are mutable

tpl = ("a", True, 5, "Red Sox")
print(tpl)

tpl[3] = "Blue" ## Note that this causes an error message, because the tuple is immutable

# %% [markdown]
# # Touples

# %%
#sets
my_set = {14, "a", 5, True, 11}
my_empty_set = set()

# %%
voted = {'will', 'sean', 'john'}
"will" in voted
# Out:
# True

# %% [markdown]
# #sets and lists
# '

# %%
papers = ["New York Times", "Washington Post", "Boston Globe", "Philadelphia Inquirer", "Atlanta Journal-Constitution"]
for i in range(len(papers)):
  papers[i] = papers[i].lower()
papers
# Out:
# ['new york times',
#  'washington post',
#  'boston globe',
#  'philadelphia inquirer',
#  'atlanta journal-constitution']

# %%
TV_news= [ 'a', 'b', 'c']
papers.extend(TV_news)
papers
# Out:
# ['new york times',
#  'washington post',
#  'boston globe',
#  'philadelphia inquirer',
#  'atlanta journal-constitution',
#  'a',
#  'b',
#  'c']
